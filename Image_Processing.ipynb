# %% [markdown]
# <a href="https://colab.research.google.com/github/rjrizani/machine-learning/blob/main/Image_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

"""x = [1, 2, 3, 4, 5]
y = [10, 12, 34, 456, 46]
"""

#make list random number
import random
x = [random.randint(1,10) for i in range(5)]
y = [random.randint(1,10) for i in range(5)]

#make list with step 2 increment
x = [i for i in range(0,5,1)]
y = [i for i in range(1,10,2)]

print(x)
print(y)

#plot the graph
plt.plot(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Graph")
plt.show()
# Out:
# [0, 1, 2, 3, 4]
# [1, 3, 5, 7, 9]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.image as mpimg
img = mpimg.imread('/content/drive/MyDrive/brightcamp/python/car_.jpg')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
#i want to know data type img var
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
import numpy as np

my_array = np.arange(5)
print("original array:", my_array)

squared_array = my_array ** 2
print("squared array:", squared_array)

sum_of_array = np.sum(squared_array)
print("sum of squared array:", sum_of_array)
# Out:
# original array: [0 1 2 3 4]
# squared array: [ 0  1  4  9 16]
# sum of squared array: 30

# %%
c = 5
m = 2
x = np.linspace(0,10,100)
print('length of x', len(x))
print()
print(x)
# Out:
# length of x 100
#
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %%
y = m*x + c
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Graph')
plt.show()
